# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# python Second code

# %%
print("*"*3)
# Out:
# ***

# %%
print("*\n"*3)
# Out:
# *
# *
# *

# %%
print("*" * 3, sep="\n")
# Out:
# ***

# %%
Name="Raju"
print(Name)
# Out:
# Raju
